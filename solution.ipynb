# %% [markdown]
# # Data Engineer Challenge Solution
#
# This notebook provides the solution for the Data Engineer Challenge. Each question is implemented and explained step-by-step.
#
# ## Question 1: Top 10 Dates with Most Tweets
#
# ### Function `q1_top_dates`
# This function identifies the 10 dates with the most tweets and the user with the most tweets on each of those dates.
#
# ```python
# from analytics import TweetAnalytics
# import pandas as pd
#
# # Load the data (assuming it's loaded from a CSV file or DataFrame)
# data = pd.read_csv('data/tweets.csv')
# analytics = TweetAnalytics(data)
#
# # Get the top 10 dates with the most tweets
# result_q1 = analytics.q1_top_dates(top_n=10)
# print(result_q1)

# %% [markdown]
# ### `solution.ipynb`
# To create the `solution.ipynb`, open Jupyter Notebook or JupyterLab, and create a new notebook file with the following structure:
#
# #### `solution.ipynb` Example Content
#
# ```markdown
# # Data Engineer Challenge Solution
#
# This notebook provides the solution for the Data Engineer Challenge. Each question is implemented and explained step-by-step.
#
# ## Question 1: Top 10 Dates with Most Tweets
#
# ### Function `q1_top_dates`
# This function identifies the 10 dates with the most tweets and the user with the most tweets on each of those dates.
#
# ```python
# from analytics import TweetAnalytics
# import pandas as pd
#
# # Load the data (assuming it's loaded from a CSV file or DataFrame)
# data = pd.read_csv('data/tweets.csv')
# analytics = TweetAnalytics(data)
#
# # Get the top 10 dates with the most tweets
# result_q1 = analytics.q1_top_dates(top_n=10)
# print(result_q1)
# ```
#
# ### Measuring Memory Usage
#
# ```python
# mem_usage_q1 = analytics.measure_memory(analytics.q1_top_dates, 10)
# print(mem_usage_q1)
# ```
#
# ## Question 2: Top 10 Most Used Emojis
#
# ### Function `q2_top_emojis`
#
# ```python
# result_q2 = analytics.q2_top_emojis(top_n=10)
# print(result_q2)
# ```
#
# ### Measuring Memory Usage
#
# ```python
# mem_usage_q2 = analytics.measure_memory(analytics.q2_top_emojis, 10)
# print(mem_usage_q2)
# ```
#
# ## Question 3: Top 10 Most Mentioned Users
#
# ### Function `q3_top_mentions`
#
# ```python
# result_q3 = analytics.q3_top_mentions(top_n=10)
# print(result_q3)
# ```
#
# ### Measuring Memory Usage
#
# ```python
# mem_usage_q3 = analytics.measure_memory(analytics.q3_top_mentions, 10)
# print(mem_usage_q3)
# ```
#
# ### Conclusion
#
# This notebook demonstrates the three requested functions and measures the memory used for each function.
